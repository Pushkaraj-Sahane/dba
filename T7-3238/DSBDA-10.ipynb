# %%
import pandas as pd 
import numpy as np
data = pd.read_csv('./Iris.csv',header=None)

data.columns = ['col1','col2','col3','col4','col5','col6']
data.head()
# Out:
#   col1           col2          col3           col4          col5         col6
# 0   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1    1            5.1           3.5            1.4           0.2  Iris-setosa
# 2    2            4.9           3.0            1.4           0.2  Iris-setosa
# 3    3            4.7           3.2            1.3           0.2  Iris-setosa
# 4    4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
column=len(list(data))
column
# Out:
# 6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    151 non-null    object
#  1   col2    151 non-null    object
#  2   col3    151 non-null    object
#  3   col4    151 non-null    object
#  4   col5    151 non-null    object
#  5   col6    151 non-null    object
# dtypes: object(6)
# memory usage: 7.2+ KB

# %%
np.unique(data['col6'])
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica', 'Species'],
#       dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig , axes = plt.subplots(2,2, figsize=(16,8))

axes[0,0].set_title('distrin=bution of first column')
axes[0,0].hist(data['col2'])

axes[0,1].set_title('distrin=bution of second column')
axes[0,1].hist(data['col3'])

axes[1,0].set_title('distrin=bution of third column')
axes[1,0].hist(data['col4'])

axes[1,1].set_title('distrin=bution of fourth column')
axes[1,1].hist(data['col5'])
# Out:
# (array([36., 13.,  2., 20., 17., 22.,  7.,  8.,  9., 17.]),
#  array([ 0. ,  2.2,  4.4,  6.6,  8.8, 11. , 13.2, 15.4, 17.6, 19.8, 22. ]),
#  <BarContainer object of 10 artists>)

# %%
fig , axes = plt.subplots(1,2, figsize=(5,2))
fig

# %%
fig

# %%
cols = data.columns.values
column = ['col2', 'col3', 'col4', 'col5']
df = data.iloc[1:, :5]
df  = df.astype(float)

# %%
df.boxplot(column)
# Out:
# <Axes: >
