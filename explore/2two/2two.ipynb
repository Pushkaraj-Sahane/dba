# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("performance.csv")

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         75.0           75.0           73.0             73.0            2020
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 4          NaN           62.0           70.0             78.0            2022
# 5         73.0           78.0           74.0              NaN            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 10        71.0            NaN           69.0             74.0            2022
# ...

# %%
df.isnull().sum()
# Out:
# math_score               2
# reading_score            1
# writing_score            1
# placement_score          1
# club_join_year           0
# placement_offer_count    0
# dtype: int64

# %%
df.dropna()
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         75.0           75.0           73.0             73.0            2020
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 11        67.0           79.0           80.0             70.0            2022
# 12        61.0           77.0           92.0             92.0            2018
# 13        72.0           74.0           78.0             97.0            2019
# ...

# %%
df.isnull().sum()
# Out:
# math_score               2
# reading_score            1
# writing_score            1
# placement_score          1
# club_join_year           0
# placement_offer_count    0
# dtype: int64

# %%
df['math_score'] = df['math_score'].fillna(df['math_score'].mean())

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            1
# writing_score            1
# placement_score          1
# club_join_year           0
# placement_offer_count    0
# dtype: int64

# %%
df['reading_score'] = df['reading_score'].fillna(df['reading_score'].mean())
df['writing_score'] = df['writing_score'].fillna(df['writing_score'].mean())
df['placement_score'] = df['placement_score'].fillna(df['placement_score'].mean())

# %%
df.isnull().sum()
# Out:
# math_score               0
# reading_score            0
# writing_score            0
# placement_score          0
# club_join_year           0
# placement_offer_count    0
# dtype: int64

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0    75.000000      75.000000      73.000000             73.0            2020
# 1    80.000000      70.000000      70.000000             78.0            2021
# 2    72.000000      64.000000      69.000000             76.0            2019
# 3    70.000000      60.000000      80.000000             96.0            2018
# 4    69.518519      62.000000      70.000000             78.0            2022
# 5    73.000000      78.000000      74.000000             82.0            2019
# 6    74.000000      64.000000      61.000000             90.0            2022
# 7    73.000000      64.000000      64.000000             95.0            2019
# 8    63.000000      66.000000      70.000000             67.0            2021
# 9    88.000000      78.000000      65.000000             79.0            2022
# 10   71.000000      70.678571      69.000000             74.0            2022
# ...

# %%
series = pd.isnull(df["math_score"])
df[series]
# Out:
# Empty DataFrame
# Columns: [math_score, reading_score, writing_score, placement_score, club_join_year, placement_offer_count]
# Index: []

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0    75.000000      75.000000      73.000000             73.0            2020
# 1    80.000000      70.000000      70.000000             78.0            2021
# 2    72.000000      64.000000      69.000000             76.0            2019
# 3    70.000000      60.000000      80.000000             96.0            2018
# 4    69.518519      62.000000      70.000000             78.0            2022
# 5    73.000000      78.000000      74.000000             82.0            2019
# 6    74.000000      64.000000      61.000000             90.0            2022
# 7    73.000000      64.000000      64.000000             95.0            2019
# 8    63.000000      66.000000      70.000000             67.0            2021
# 9    88.000000      78.000000      65.000000             79.0            2022
# 10   71.000000      70.678571      69.000000             74.0            2022
# ...

# %%
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0    75.000000      75.000000      73.000000             73.0            2020
# 1    80.000000      70.000000      70.000000             78.0            2021
# 2    72.000000      64.000000      69.000000             76.0            2019
# 3    70.000000      60.000000      80.000000             96.0            2018
# 4    69.518519      62.000000      70.000000             78.0            2022
# 5    73.000000      78.000000      74.000000             82.0            2019
# 6    74.000000      64.000000      61.000000             90.0            2022
# 7    73.000000      64.000000      64.000000             95.0            2019
# 8    63.000000      66.000000      70.000000             67.0            2021
# 9    88.000000      78.000000      65.000000             79.0            2022
# 10   71.000000      70.678571      69.000000             74.0            2022
# ...

# %%
df.notnull()
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
missing_values = ["Na","na"]
df = pd.read_csv("performance.csv", na_values = missing_values)
df
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         75.0           75.0           73.0             73.0            2020
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 4          NaN           62.0           70.0             78.0            2022
# 5         73.0           78.0           74.0              NaN            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 10        71.0            NaN           69.0             74.0            2022
# ...

# %%
ndf=df
ndf.fillna(0)
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         75.0           75.0           73.0             73.0            2020
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 4          0.0           62.0           70.0             78.0            2022
# 5         73.0           78.0           74.0              0.0            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 10        71.0            0.0           69.0             74.0            2022
# ...

# %%
ndf.replace(to_replace = np.nan, value = -99.00)
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 0         75.0           75.0           73.0             73.0            2020
# 1         80.0           70.0           70.0             78.0            2021
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 4        -99.0           62.0           70.0             78.0            2022
# 5         73.0           78.0           74.0            -99.0            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 9         88.0           78.0           65.0             79.0            2022
# 10        71.0          -99.0           69.0             74.0            2022
# ...

# %%
#detectoutliers
df.columns
# Out:
# Index(['math_score', 'reading_score', 'writing_score', 'placement_score',
#        'club_join_year', 'placement_offer_count'],
#       dtype='object')

# %%
col = ['math_score', 'reading_score', 'writing_score']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math_score']>85))
# Out:
# (array([9], dtype=int64),)

# %%
newdf = df[df['math_score']<80]
newdf
# Out:
#     math_score  reading_score  writing_score  placement_score  club_join_year  \
# 2         72.0           64.0           69.0             76.0            2019
# 3         70.0           60.0           80.0             96.0            2018
# 5         73.0           78.0           74.0              NaN            2019
# 6         74.0           64.0           61.0             90.0            2022
# 7         73.0           64.0           64.0             95.0            2019
# 8         63.0           66.0           70.0             67.0            2021
# 10        71.0            NaN           69.0             74.0            2022
# 11        67.0           79.0           80.0             70.0            2022
# 13        72.0           74.0           78.0             97.0            2019
# 14        62.0           72.0           62.0             95.0            2022
# 15        69.0           60.0           78.0             80.0            2020
# ...

# %%
newdf.boxplot(col)
# Out:
# <Axes: >

# %%
df['math_score'].median()
# Out:
# 71.0
